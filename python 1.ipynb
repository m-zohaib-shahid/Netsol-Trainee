# %% [markdown]
# # Python Fundamentals — Guided Notebook
# ## Lectures 1 & 2
#
# This notebook is designed for people who are **new to Python**.
#
# You will learn by repeating a simple cycle:
#
# > **Read → Predict → Run → Change → Practice**
#
# The goal is not to memorize syntax. It is to understand what Python is doing.
#
# ---
#
# ## What we will cover
#
# ### Lecture 1 — Python Fundamentals & Data Structures
# - Values, expressions, and statements
# - Numbers, Booleans, and strings
# - Variables and operators
# - String operations
# - Input and type casting
# - Comments
# - Lists, tuples, dictionaries, and sets
#
# ### Lecture 2 — Control Flow, Loops & Functions
# - `if`, `elif`, and `else`
# - Nested and ternary conditionals
# - `break`, `continue`, and `pass`
# - `while` and `for` loops
# - `enumerate`
# - Nested loops
# - List comprehensions
# - Iterables and iterators
# - Functions
# - Variable scope
# - Keyword arguments
# - Lambda expressions
# - `map` and `filter`
# - Inner / nested functions
#
# ---
#
# ### A useful habit
#
# Before running a code cell, try to answer:
#
# 1. What values exist?
# 2. What operation will Python perform?
# 3. What do I expect the output to be?
#
# That habit is much more valuable than memorizing code.

# %% [markdown]
# ## How to use code cells
#
# Run a code cell with **Shift + Enter**.
#
# Try this first cell. `print()` tells Python to display something.

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %% [markdown]
# # Lecture 1 — Python Fundamentals & Data Structures

# %% [markdown]
# ## 1. Values, expressions, and statements
#
# A **value** is a piece of data.
#
# Examples:
# - `42`
# - `3.14`
# - `"hello"`
# - `True`
#
# An **expression** combines values and operators to produce a new value.
#
# ```python
# 2 + 3
# ```
#
# A **statement** tells Python to do something.
#
# ```python
# score = 10
# ```
#
# Here, `score = 10` stores a value in a variable.

# %%
print(42)
print(2 + 3)

score = 10
print(score)
# Out:
# 42
# 5
# 10

# %% [markdown]
# ### Predict before running
#
# What do you think each expression will produce?

# %%
print(10 + 5)
print(10 - 5)
print(10 * 5)
print(10 / 5)
# Out:
# 15
# 5
# 50
# 2.0

# %% [markdown]
# ## 2. Numbers, Booleans, and strings
#
# Python values have **types**.
#
# Three important beginner types are:
#
# | Type | Example | Meaning |
# |---|---|---|
# | `int` | `25` | whole number |
# | `float` | `25.5` | decimal number |
# | `bool` | `True` | true/false value |
# | `str` | `"Python"` | text |
#
# Use `type()` to ask Python what type a value has.

# %%
print(type(25))
print(type(25.5))
print(type(True))
print(type("Python"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# ## 3. Variables
#
# A variable is a **name that refers to a value**.
#
# Think of it as a label.
#
# ```python
# age = 18
# ```
#
# The name is `age`; the value is `18`.
#
# Variable names:
# - can contain letters, numbers, and `_`
# - cannot start with a number
# - are case-sensitive: `score` and `Score` are different
# - cannot use reserved keywords such as `if`, `for`, or `class`

# %%
name = "Ayesha"
age = 18
height = 1.67
is_student = True

print(name)
print(age)
print(height)
print(is_student)
# Out:
# Ayesha
# 18
# 1.67
# True

# %% [markdown]
# ### Variables can change
#
# The `=` symbol in Python means **assign**.
#
# It does not mean mathematical equality.

# %%
score = 10
print("Before:", score)

score = score + 5
print("After:", score)
# Out:
# Before: 10
# After: 15

# %% [markdown]
# ## 4. Operators
#
# ### Arithmetic operators
#
# | Operator | Meaning |
# |---|---|
# | `+` | addition |
# | `-` | subtraction |
# | `*` | multiplication |
# | `/` | division |
# | `//` | floor division |
# | `%` | remainder |
# | `**` | exponent |
#
# The `%` operator is especially useful for checking whether a number is even or odd.

# %%
number = 17

print(number / 5)
print(number // 5)
print(number % 5)
print(2 ** 4)
# Out:
# 3.4
# 3
# 2
# 16

# %% [markdown]
# ### Comparison operators
#
# Comparisons produce Boolean values: `True` or `False`.

# %%
age = 20

print(age == 20)
print(age != 20)
print(age > 18)
print(age <= 19)
# Out:
# True
# False
# True
# False

# %% [markdown]
# ### Logical operators
#
# Use:
# - `and` when **both** conditions must be true
# - `or` when **at least one** condition must be true
# - `not` to reverse a Boolean value

# %%
age = 20
has_id = True

print(age >= 18 and has_id)
print(age < 18 or has_id)
print(not has_id)
# Out:
# True
# True
# False

# %% [markdown]
# ## 5. Strings
#
# A string is text surrounded by quotes.
#
# You can use either:
#
# ```python
# "hello"
# 'hello'
# ```
#
# Strings can be joined with `+`.

# %%
first_name = "Ali"
last_name = "Khan"

full_name = first_name + " " + last_name
print(full_name)
# Out:
# Ali Khan

# %% [markdown]
# ### Useful string operations
#
# Python strings support:
# - `len(text)` — number of characters
# - `text.lower()` — lowercase
# - `text.upper()` — uppercase
# - `text.strip()` — remove whitespace at the ends
# - `text.replace(a, b)` — replace text
# - indexing such as `text[0]`
# - slicing such as `text[0:3]`

# %%
message = "  Learn Python  "

print(len(message))
print(message.strip())
print(message.lower())
print(message.upper())
print(message.replace("Python", "Programming"))

word = "Python"
print(word[0])
print(word[-1])
print(word[0:3])
# Out:
# 16
# Learn Python
#   learn python
#   LEARN PYTHON
#   Learn Programming
# P
# n
# Pyt

# %% [markdown]
# ### f-strings
#
# f-strings are the easiest way to place variables inside text.

# %%
name = "Sara"
score = 92

print(f"{name} scored {score} marks.")
# Out:
# Sara scored 92 marks.

# %% [markdown]
# ## 6. Input and type casting
#
# `input()` lets a user type a value.
#
# Important: **`input()` always returns a string.**
#
# So if you want to perform arithmetic, you often need type casting:
#
# ```python
# int("25")
# float("3.5")
# str(100)
# ```
#
# The next example is written without `input()` so the notebook can run automatically.

# %%
typed_age = "19"

print(type(typed_age))

age = int(typed_age)

print(type(age))
print(age + 1)
# Out:
# <class 'str'>
# <class 'int'>
# 20

# %% [markdown]
# ### Try real input
#
# Run this cell manually and type your own name and age.

# %%
# Uncomment these lines when you want to try interactive input:
name = input("What is your name? ")
age = int(input("How old are you? "))
print(f"Hello {name}. Next year you will be {age + 1}.")
# Out:
# Hello Zohaib. Next year you will be 22.

# %% [markdown]
# ## 7. Comments
#
# Comments are notes for humans. Python ignores them.
#
# Use `#` for a comment.

# %%
# Calculate the price after a 10% discount
price = 2000
discount = 0.10

final_price = price * (1 - discount)
print(final_price)
# Out:
# 1800.0

# %% [markdown]
# ## 8. Data Structures

# %% [markdown]
# ### Lists
#
# A list stores multiple values **in order**.
#
# Lists are **mutable**, which means they can be changed.

# %%
fruits = ["apple", "banana", "mango"]

print(fruits)
print(fruits[0])

fruits.append("orange")
print(fruits)

fruits[1] = "strawberry"
print(fruits)
# Out:
# ['apple', 'banana', 'mango']
# apple
# ['apple', 'banana', 'mango', 'orange']
# ['apple', 'strawberry', 'mango', 'orange']

# %% [markdown]
# ### Tuples
#
# A tuple is also ordered, but it is usually used for values that should **not change**.
#
# Tuples are **immutable**.

# %%
point = (10, 20)

print(point)
print(point[0])
print(point[1])
# Out:
# (10, 20)
# 10
# 20

# %% [markdown]
# ### Dictionaries
#
# A dictionary stores **key-value pairs**.
#
# Instead of asking for item `0`, you usually ask for an item by name.

# %%
student = {
    "name": "Hassan",
    "age": 19,
    "score": 88
}

print(student["name"])
print(student["score"])

student["score"] = 91
student["city"] = "Lahore"

print(student)
# Out:
# Hassan
# 88
# {'name': 'Hassan', 'age': 19, 'score': 91, 'city': 'Lahore'}

# %% [markdown]
# ### Sets
#
# A set stores **unique values**.
#
# Sets are useful when duplicates do not matter.

# %%
topics = {"python", "math", "python", "physics"}

print(topics)

topics.add("statistics")
print(topics)
# Out:
# {'math', 'python', 'physics'}
# {'math', 'statistics', 'python', 'physics'}

# %% [markdown]
# ## Lecture 1 — Practice

# %% [markdown]
# ### Exercise 1 — Build a student profile
#
# Create variables for:
# - name
# - age
# - favorite subject
# - whether the student likes Python
#
# Then print one sentence using an f-string.

# %%
# TODO: create the variables and print a sentence
# Example idea:
# "Mina is 18 years old, likes Mathematics, and likes Python: True"
name = "meena"
age="19"
print(name + "is" + age + "old")
...
# Out:
# meenais19old
# Ellipsis

# %% [markdown]
# ### Exercise 2 — Temperature conversion
#
# Convert `30°C` to Fahrenheit.
#
# Formula:
#
# \[
# F = C \times \frac{9}{5} + 32
# \]

# %%
celsius = 30

# TODO: calculate fahrenheit
fahrenheit = (celsius*9/5)+32

# TODO: print the result
print(fahrenheit)
# Out:
# 86.0

# %% [markdown]
# ### Exercise 3 — Work with a list
#
# Given the list below:
#
# 1. Print the first subject
# 2. Add `"Computer Science"`
# 3. Replace `"Chemistry"` with `"Biology"`
# 4. Print the final list

# %%
subjects = ["Math", "Physics", "Chemistry"]

# TODO
subjects.append("computer Science")
print(subjects)
subjects[2]="Biology"
print(subjects)
# Out:
# ['Math', 'Physics', 'Chemistry', 'computer Science']
# ['Math', 'Physics', 'Biology', 'computer Science']

# %% [markdown]
# ### Exercise 4 — Work with a dictionary
#
# Create a dictionary named `course` with:
# - title: `"Introduction to Python"`
# - weeks: `4`
# - students: `30`
#
# Then:
# 1. Print the title
# 2. Change students to `32`
# 3. Add a key called `"level"` with value `"Beginner"`

# %%
# TODO: create and update the dictionary
course = {
    "title":"Introduction to Python",
    "weeks": 4,
    "students": 30
}
print(course["title"])
course["students"] = 32
course["level"]="Beginner"
print(course)

...
# Out:
# Introduction to Python
# {'title': 'Introduction to Python', 'weeks': 4, 'students': 32, 'level': 'Beginner'}
# Ellipsis

# %% [markdown]
# ### Exercise 5 — Remove duplicates
#
# Use a set to find the unique programming languages.

# %%
languages = ["Python", "Java", "Python", "C++", "Java", "Python"]

# TODO: convert languages to a set
unique_languages = {"Python", "Java", "Python", "C++", "Java", "Python"}

print(unique_languages)
# Out:
# {'Java', 'Python', 'C++'}

# %% [markdown]
# # Lecture 2 — Control Flow, Loops & Functions

# %% [markdown]
# ## 9. Conditional execution
#
# Programs become useful when they can make decisions.
#
# The basic structure is:
#
# ```python
# if condition:
#     ...
# elif another_condition:
#     ...
# else:
#     ...
# ```
#
# Python uses **indentation** to show which code belongs to each branch.

# %%
temperature = 34

if temperature > 35:
    print("Very hot")
elif temperature > 25:
    print("Warm")
else:
    print("Cool")
# Out:
# Warm

# %% [markdown]
# ### Multiple conditions
#
# Logical operators let us combine conditions.

# %%
age = 20
has_ticket = True

if age >= 18 and has_ticket:
    print("You may enter.")
else:
    print("Entry denied.")
# Out:
# You may enter.

# %% [markdown]
# ### Nested conditionals
#
# A conditional can exist inside another conditional.
#
# Use nesting when the second decision only matters after the first one.

# %%
logged_in = True
is_admin = False

if logged_in:
    print("Welcome!")

    if is_admin:
        print("Admin panel enabled.")
    else:
        print("Standard account.")
else:
    print("Please log in.")
# Out:
# Welcome!
# Standard account.

# %% [markdown]
# ### Ternary expression
#
# A ternary expression is a short one-line conditional.
#
# ```python
# value_if_true if condition else value_if_false
# ```
#
# Use it for **small, simple decisions**.

# %%
age = 17

status = "Adult" if age >= 18 else "Minor"
print(status)
# Out:
# Minor

# %% [markdown]
# ## 10. `break`, `continue`, and `pass`
#
# - `break` — stop the loop completely
# - `continue` — skip the rest of this iteration
# - `pass` — do nothing; useful as a placeholder

# %%
for number in range(1, 8):
    if number == 5:
        break
    print(number)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Here, `continue` skips even numbers.

# %%
for number in range(1, 8):
    if number % 2 == 0:
        continue
    print(number)
# Out:
# 1
# 3
# 5
# 7

# %% [markdown]
# `pass` is useful when you want to create a block now and fill it in later.

# %%
if True:
    pass

print("The program continues.")
# Out:
# The program continues.

# %% [markdown]
# ## 11. `while` loops
#
# A `while` loop repeats **while a condition is true**.
#
# Be careful: if the condition never becomes false, you create an infinite loop.

# %%
count = 1

while count <= 5:
    print(count)
    count = count + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## 12. `for` loops
#
# A `for` loop is usually used to visit items in a collection.

# %%
subjects = ["Math", "Physics", "Python"]

for subject in subjects:
    print(subject)
# Out:
# Math
# Physics
# Python

# %% [markdown]
# ### `range()`
#
# `range()` is commonly used when you want a sequence of integers.
#
# `range(5)` produces values from `0` up to, but not including, `5`.

# %%
for number in range(5):
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### `enumerate()`
#
# `enumerate()` gives both:
# - the index
# - the value
#
# This is cleaner than manually keeping a counter.

# %%
students = ["Aisha", "Bilal", "Hira"]

for index, student in enumerate(students):
    print(index, student)
# Out:
# 0 Aisha
# 1 Bilal
# 2 Hira

# %% [markdown]
# Use `start=1` when you want human-friendly numbering.

# %%
students = ["Aisha", "Bilal", "Hira"]

for number, student in enumerate(students, start=1):
    print(f"{number}. {student}")
# Out:
# 1. Aisha
# 2. Bilal
# 3. Hira

# %% [markdown]
# ## 13. Nested loops
#
# A nested loop is a loop inside another loop.
#
# The inner loop finishes all of its iterations for **each** outer-loop iteration.

# %%
for row in range(1, 4):
    for column in range(1, 4):
        print(f"row={row}, column={column}")
# Out:
# row=1, column=1
# row=1, column=2
# row=1, column=3
# row=2, column=1
# row=2, column=2
# row=2, column=3
# row=3, column=1
# row=3, column=2
# row=3, column=3

# %% [markdown]
# ## 14. List comprehensions
#
# A list comprehension is a compact way to build a list.
#
# Traditional version:

# %%
squares = []

for number in range(1, 6):
    squares.append(number ** 2)

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# The same idea as a list comprehension:

# %%
squares = [number ** 2 for number in range(1, 6)]

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# You can also add a condition.

# %%
even_squares = [
    number ** 2
    for number in range(1, 11)
    if number % 2 == 0
]

print(even_squares)
# Out:
# [4, 16, 36, 64, 100]

# %% [markdown]
# ## 15. Iterables and iterators
#
# An **iterable** is something you can loop over.
#
# Examples:
# - list
# - tuple
# - string
# - dictionary
# - set
#
# An **iterator** is the object that gives items **one at a time**.
#
# You usually do not create iterators manually because a `for` loop handles this for you.
#
# But we can see the mechanism:

# %%
colors = ["red", "green", "blue"]

iterator = iter(colors)

print(next(iterator))
print(next(iterator))
print(next(iterator))
# Out:
# red
# green
# blue

# %% [markdown]
# ### What a `for` loop is roughly doing
#
# This:
#
# ```python
# for color in colors:
#     print(color)
# ```
#
# is conceptually similar to repeatedly calling `next()` on an iterator until there are no items left.
#
# You do **not** need to memorize the internal mechanism yet. The important idea is:
#
# > **Iterable = something we can iterate over. Iterator = object that produces the next item.**

# %% [markdown]
# ## 16. Functions
#
# A function packages reusable behavior.
#
# ```python
# def function_name(parameters):
#     ...
#     return result
# ```
#
# Use functions when you notice yourself doing the same kind of task repeatedly.

# %%
def greet(name):
    return f"Hello, {name}!"

message = greet("Noor")
print(message)
# Out:
# Hello, Noor!

# %% [markdown]
# ### Parameters and arguments
#
# In:
#
# ```python
# def greet(name):
# ```
#
# `name` is a **parameter**.
#
# In:
#
# ```python
# greet("Noor")
# ```
#
# `"Noor"` is an **argument**.

# %%
def add(a, b):
    return a + b

result = add(4, 7)
print(result)
# Out:
# 11

# %% [markdown]
# ### Keyword arguments
#
# You can pass arguments by parameter name.
#
# This often makes function calls easier to read.

# %%
def create_profile(name, age, city):
    return f"{name}, age {age}, from {city}"

print(create_profile(age=20, city="Lahore", name="Zain"))
# Out:
# Zain, age 20, from Lahore

# %% [markdown]
# ## 17. Variable scope
#
# A variable created inside a function is usually **local** to that function.
#
# A variable created outside a function is usually **global**.
#
# Prefer local variables when possible. They make code easier to reason about.

# %%
course_name = "Python"   # global

def show_course():
    room = "Lab 2"          # local
    print(course_name)
    print(room)

show_course()

# print(room)  # This would cause an error because room is local.
# Out:
# Python
# Lab 2

# %% [markdown]
# ## 18. Lambda expressions
#
# A lambda is a small anonymous function.
#
# Normal function:

# %%
def square(x):
    return x ** 2

print(square(5))
# Out:
# 25

# %% [markdown]
# Equivalent lambda:

# %%
square = lambda x: x ** 2

print(square(5))
# Out:
# 25

# %% [markdown]
# ## 19. `map()` and `filter()`
#
# `map()` applies a function to every item.
#
# `filter()` keeps items that satisfy a condition.
#
# In modern Python, list comprehensions are often easier to read, but `map()` and `filter()` are still important concepts.

# %%
numbers = [1, 2, 3, 4, 5]

squared = list(map(lambda x: x ** 2, numbers))
evens = list(filter(lambda x: x % 2 == 0, numbers))

print(squared)
print(evens)
# Out:
# [1, 4, 9, 16, 25]
# [2, 4]

# %% [markdown]
# ## 20. Inner / nested functions
#
# A function can be defined inside another function.
#
# This is useful when the inner helper only makes sense inside the outer function.

# %%
def format_student(name, score):
    def format_score(value):
        return f"{value}%"

    return f"{name}: {format_score(score)}"

print(format_student("Amna", 87))
# Out:
# Amna: 87%

# %% [markdown]
# ## Lecture 2 — Practice

# %% [markdown]
# ### Exercise 6 — Grade classifier
#
# Given a score:
#
# - `90+` → `"A"`
# - `80–89` → `"B"`
# - `70–79` → `"C"`
# - below `70` → `"Needs Improvement"`
#
# Write the conditional logic.

# %%
score = 84

# TODO: assign the correct grade
grade = ...

print(grade)
# Out:
# Ellipsis

# %% [markdown]
# ### Exercise 7 — Find the first multiple of 7
#
# Loop through numbers from `1` to `50`.
#
# Stop as soon as you find the first number greater than `20` that is divisible by `7`.

# %%
# TODO
...

# %% [markdown]
# ### Exercise 8 — Skip unwanted values
#
# Print the numbers from `1` to `10`, but skip multiples of `3`.

# %%
# TODO
...

# %% [markdown]
# ### Exercise 9 — Numbered class list
#
# Use `enumerate()` to print:
#
# ```text
# 1. Aisha
# 2. Bilal
# 3. Hira
# 4. Omar
# ```

# %%
students = ["Aisha", "Bilal", "Hira", "Omar"]

# TODO
...
# Out:
# Ellipsis

# %% [markdown]
# ### Exercise 10 — Build a list with a comprehension
#
# Create a list containing the cubes of numbers `1` through `5`.
#
# Expected result:
#
# ```python
# [1, 8, 27, 64, 125]
# ```

# %%
# TODO
cubes = ...

print(cubes)
# Out:
# Ellipsis

# %% [markdown]
# ### Exercise 11 — Write a function
#
# Create a function named `is_even(number)` that returns `True` when a number is even and `False` otherwise.

# %%
def is_even(number):
    # TODO
    ...

# Try it
# print(is_even(8))
# print(is_even(5))

# %% [markdown]
# ### Exercise 12 — Function with keyword arguments
#
# Create a function called `final_price(price, discount_percent=0)`.
#
# It should return the price after applying the percentage discount.
#
# Example:
#
# ```python
# final_price(price=1000, discount_percent=20)
# ```
#
# should return `800`.

# %%
def final_price(price, discount_percent=0):
    # TODO
    ...

# TODO: call the function using keyword arguments

# %% [markdown]
# ### Exercise 13 — `map()` and `filter()`
#
# Given the list below:
#
# 1. Use `filter()` to keep only scores `>= 70`
# 2. Use `map()` to add `5` bonus marks to each remaining score

# %%
scores = [55, 72, 68, 91, 80, 49]

# TODO
passing_scores = ...
bonus_scores = ...

print(passing_scores)
print(bonus_scores)
# Out:
# Ellipsis
# Ellipsis

# %% [markdown]
# # Mini Project — Student Result Analyzer
#
# This combines many ideas from Lectures 1 and 2.
#
# We have a list of student dictionaries:
#
# ```python
# students = [
#     {"name": "Aisha", "score": 88},
#     {"name": "Bilal", "score": 67},
#     {"name": "Hira", "score": 94},
#     {"name": "Omar", "score": 73},
# ]
# ```
#
# Your program should:
#
# 1. Create a function `get_grade(score)`
# 2. Return:
#    - `A` for 90+
#    - `B` for 80–89
#    - `C` for 70–79
#    - `Needs Improvement` below 70
# 3. Loop over all students
# 4. Print a numbered report such as:
#
# ```text
# 1. Aisha — 88 — B
# 2. Bilal — 67 — Needs Improvement
# ...
# ```
#
# 5. Count how many students scored at least 70
# 6. Print the final count

# %%
students = [
    {"name": "Aisha", "score": 88},
    {"name": "Bilal", "score": 67},
    {"name": "Hira", "score": 94},
    {"name": "Omar", "score": 73},
]

# TODO 1: write get_grade(score)
def get_grade(score):
    ...

# TODO 2: create a counter for passing students

# TODO 3: loop over students using enumerate(..., start=1)

# TODO 4: print each student's number, name, score, and grade

# TODO 5: print how many students scored at least 70

# %% [markdown]
# # Quick Reference
#
# ## Values and variables
# ```python
# age = 18
# name = "Ali"
# is_student = True
# ```
#
# ## List
# ```python
# subjects = ["Math", "Physics"]
# subjects.append("Python")
# ```
#
# ## Dictionary
# ```python
# student = {"name": "Ali", "score": 90}
# student["score"]
# ```
#
# ## Conditional
# ```python
# if score >= 70:
#     print("Pass")
# else:
#     print("Try again")
# ```
#
# ## Loop
# ```python
# for item in items:
#     print(item)
# ```
#
# ## Function
# ```python
# def add(a, b):
#     return a + b
# ```
#
# ## The big picture
#
# By the end of these two lectures, you should be able to read a small Python program and answer:
#
# - What data is being stored?
# - What type is each value?
# - What decisions does the program make?
# - What gets repeated?
# - What functionality has been packaged into functions?
#
# If you can answer those questions, you are already beginning to **think like a programmer**.
